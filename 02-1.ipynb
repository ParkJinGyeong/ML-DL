# %%
import pandas as pd

# %%
df = pd.read_csv('data/Fish.csv')
df.head()
# Out:
#   Species  Weight  Length1  Length2  Length3   Height   Width
# 0   Bream   242.0     23.2     25.4     30.0  11.5200  4.0200
# 1   Bream   290.0     24.0     26.3     31.2  12.4800  4.3056
# 2   Bream   340.0     23.9     26.5     31.1  12.3778  4.6961
# 3   Bream   363.0     26.3     29.0     33.5  12.7300  4.4555
# 4   Bream   430.0     26.5     29.0     34.0  12.4440  5.1340

# %%
cond = df['Species'].isin(['Bream','Smelt']) #b와 s가 아닌 부분은 false

# %%
df.loc[cond] #cond에 맞는 애들을 슬라이싱
# Out:
#     Species  Weight  Length1  Length2  Length3   Height   Width
# 0     Bream   242.0     23.2     25.4     30.0  11.5200  4.0200
# 1     Bream   290.0     24.0     26.3     31.2  12.4800  4.3056
# 2     Bream   340.0     23.9     26.5     31.1  12.3778  4.6961
# 3     Bream   363.0     26.3     29.0     33.5  12.7300  4.4555
# 4     Bream   430.0     26.5     29.0     34.0  12.4440  5.1340
# 5     Bream   450.0     26.8     29.7     34.7  13.6024  4.9274
# 6     Bream   500.0     26.8     29.7     34.5  14.1795  5.2785
# 7     Bream   390.0     27.6     30.0     35.0  12.6700  4.6900
# 8     Bream   450.0     27.6     30.0     35.1  14.0049  4.8438
# 9     Bream   500.0     28.5     30.7     36.2  14.2266  4.9594
# 10    Bream   475.0     28.4     31.0     36.2  14.2628  5.1042
# 11    Bream   500.0     28.7     31.0     36.2  14.3714  4.8146
# 12    Bream   500.0     29.1     31.5     36.4  13.7592  4.3680
# 13    Bream   340.0     29.5     32.0     37.3  13.9129  5.0728
# ...

# %%
lw_df = df.loc[cond, ['Length2', 'Weight']] #필요한 칼럼만 뽑아내기

# %%
#lw_df에 들어있는 값만 알고 싶습니다 
#2차원으로 바꾸고 싶은 상황 
fish_data = lw_df.values.tolist()

# %%
from sklearn.neighbors import KNeighborsClassifier
kn = KNeighborsClassifier

# %%
fish_target = [1]*35 + [0]*14

# %%
train_input = fish_data[:35]
train_target = fish_target[:35]

test_input = fish_data[:35]
test_target = fish_target[:35]

# %%
kn.fit(train_input, train_target)
kn.score(test_input, test_target)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[36], line 1
# ----> 1 kn.fit(train_input, train_target)
#       2 kn.score(test_input, test_target)
#
# File ~\Desktop\DMF\ML\venv\Lib\site-packages\sklearn\base.py:1466, in _fit_context.<locals>.decorator.<locals>.wrapper(estimator, *args, **kwargs)
#    1461 partial_fit_and_fitted = (
#    1462     fit_method.__name__ == "partial_fit" and _is_fitted(estimator)
#    1463 )
#    1465 if not global_skip_validation and not partial_fit_and_fitted:
# -> 1466     estimator._validate_params()
#    1468 with config_context(
#    1469     skip_parameter_validation=(
#    1470         prefer_skip_nested_validation or global_skip_validation
#    1471     )
#    1472 ):
#    1473     return fit_method(estimator, *args, **kwargs)
#
# AttributeError: 'list' object has no attribute '_validate_params'

# %%
import numpy as np

# %%
fish_arr = np.array(fish_data)
target_arr = np.array(fish_target)
#넘파이 활용해서 강제로 array로 바꿈 #fancy 인덱싱 가능

# %%
np.random.seed(42)
index = np.arange(49) #0~49 만들어서 
np.random.shuffle(index) #랜덤으로 말해줘 
print(index)
# Out:
# [13 45 47 44 17 27 26 25 31 19 12  4 34  8  3  6 40 41 46 15  9 16 24 33
#  30  0 43 32  5 29 11 36  1 21  2 37 35 23 39 10 22 18 48 20  7 42 14 28
#  38]

# %%
test_input = fish_arr[index[:35]]
train_target = target_arr[index[:35]]

test_input = fish_arr[index[:35]]
test_target = target_arr[index[:35]]

# %%
import matplotlib.pyplot as plt

plt.scatter(train_input[;, 0], train_input[;, 1])
plt.show()
# Out:
#   Cell In[56], line 3
#     plt.scatter(train_input[;, 0], train_input[;, 1])
#                             ^
# SyntaxError: invalid syntax
